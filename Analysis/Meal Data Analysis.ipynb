# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
data = pd.read_csv('mealData.csv',header=None)
data = data.apply(lambda x: x.astype(str).str.lower())
data.to_csv('mealdataout.csv')

# %%
dataIng = data.iloc[:,1:]

# %%
pd.Series(dataIng.values.ravel('K')).unique()
# Out:
# array([' roast lamb', ' beef tomato casserole', ' main salad',
#        ' beef mexican meatballs', ' sandwich',
#        ' spinach and pumpkin risotto', ' baked fish', ' gravy',
#        ' creamed potato', ' bread', ' boiled rice', ' soup',
#        ' seasonal vegetables', ' tartare sauce', ' jacket potato',
#        ' margarine', ' side salad', ' juice', ' lemon sponge',
#        ' vanilla yoghurt', ' jelly', ' canned fruit', ' water', ' milk',
#        ' custard', 'nan'], dtype=object)

# %%
pd.Series(dataIng.values.ravel('K')).value_counts().iloc[1:].plot('bar')
